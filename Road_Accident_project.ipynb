# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
df= pd.read_csv(r"C:\Users\shivani\Downloads\Regulatory Affairs of Road Accident Data 2020 India.csv")

# %%
df
# Out:
#      Million Plus Cities   Cause category        Cause Subcategory  \
# 0                   Agra  Traffic Control  Flashing Signal/Blinker
# 1                   Agra  Traffic Control  Flashing Signal/Blinker
# 2                   Agra  Traffic Control  Flashing Signal/Blinker
# 3                   Agra  Traffic Control  Flashing Signal/Blinker
# 4                   Agra  Traffic Control  Flashing Signal/Blinker
# ...                  ...              ...                      ...
# 9545               Vizaq          Weather              Sunny/Clear
# 9546               Vizaq          Weather              Sunny/Clear
# 9547               Vizaq          Weather              Sunny/Clear
# 9548               Vizaq          Weather              Sunny/Clear
# 9549               Vizaq          Weather              Sunny/Clear
#
#             Outcome of Incident   Count
# 0            Greviously Injured     0.0
# 1                  Minor Injury     0.0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #  To check Missing Values

# %%
df.isna().sum()
# Out:
# Million Plus Cities    0
# Cause category         0
# Cause Subcategory      0
# Outcome of Incident    0
# Count                  3
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Million Plus Cities    0
# Cause category         0
# Cause Subcategory      0
# Outcome of Incident    0
# Count                  0
# dtype: int64

# %%
df.dtypes
# Out:
# Million Plus Cities     object
# Cause category          object
# Cause Subcategory       object
# Outcome of Incident     object
# Count                  float64
# dtype: object

# %% [markdown]
# # To check statistical summary

# %%
df.describe()
# Out:
#              Count
# count  9547.000000
# mean    103.627632
# std     275.189303
# min       0.000000
# 25%       0.000000
# 50%      12.000000
# 75%      70.500000
# max    3148.000000

# %% [markdown]
# # EDA on Data

# %% [markdown]
# #  To Identify the cities with the highest number of accidents.

# %%
total_accidents = df[df['Outcome of Incident']=="Total number of Accidents"]

# %%
total_accidents
# Out:
#      Million Plus Cities   Cause category        Cause Subcategory  \
# 4                   Agra  Traffic Control  Flashing Signal/Blinker
# 9                   Agra  Traffic Control                   Others
# 14                  Agra  Traffic Control        Police Controlled
# 19                  Agra  Traffic Control                Stop Sign
# 24                  Agra  Traffic Control     Traffic Light Signal
# ...                  ...              ...                      ...
# 9528               Vizaq          Weather          Foggy and Misty
# 9533               Vizaq          Weather               Hail/Sleet
# 9538               Vizaq          Weather                   Others
# 9543               Vizaq          Weather                    Rainy
# 9548               Vizaq          Weather              Sunny/Clear
#
#             Outcome of Incident   Count
# 4     Total number of Accidents     0.0
# 9     Total number of Accidents   470.0
# ...

# %%
data=df.groupby('Million Plus Cities').sum()[['Count']].sort_values('Count',ascending=False)

# %%
data
# Out:
#                         Count
# Million Plus Cities
# Chennai               78459.0
# Delhi                 72526.0
# Jabalpur              57715.0
# Bengaluru             53535.0
# Indore                50098.0
# Bhopal                35069.0
# Hyderabad             34720.0
# Jaipur                32524.0
# Mallapuram            32294.0
# Mumbai                32106.0
# Raipur                27722.0
# Thrissur              27540.0
# Gwalior               27309.0
# Kolkata               26715.0
# Vizaq                 25122.0
# Kollam                24821.0
# Kochi                 24694.0
# Thiruvanthapuram      21825.0
# Kanpur                19280.0
# Vijaywada city        18823.0
# Allahabad(Prayagraj)  18066.0
# Ahmedabad             17796.0
# Khozikode             17696.0
# Agra                  15483.0
# Nagpur                14170.0
# Lucknow               14014.0
# Coimbatore            12574.0
# Meerut                11801.0
# Ghaziabad             11319.0
# ...

# %%
plt.figure(figsize=(12, 6))
plt.bar(data.index, data['Count'], edgecolor='black',color='#EF4B4B')

plt.title('Cities by Maximum Accident Count', fontsize=18,fontweight='bold')
plt.xlabel('Million Plus Cities', fontsize=18,fontweight='bold')
plt.ylabel('Maximum Accident Count', fontsize=14,fontweight='bold')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.gcf().set_facecolor('#B3C99C')

plt.show()

# %% [raw]
# The bar chart highlights the cities with the highest accident counts in "Million Plus Cities." Chennai leads with the highest accident count (78,459), followed by Delhi (72,526) and Jabalpur (57,715). Major metropolitan cities like Bengaluru, Indore, and Hyderabad also rank high, reflecting a higher traffic density and associated risk. The chart shows a clear concentration of accidents in larger urban areas, particularly in central, western, and southern cities such as Jaipur, Kolkata, and Mumbai.
#
# Cities with lower counts like Jamshedpur, Dhanbad, Chandigarh, and Amritsar report fewer accidents, which could be attributed to differing traffic conditions or more effective safety measures. The visualization suggests a need for targeted interventions in high-risk cities to reduce accidents and improve road safety.

# %%
df.head()
# Out:
#   Million Plus Cities   Cause category        Cause Subcategory  \
# 0                Agra  Traffic Control  Flashing Signal/Blinker
# 1                Agra  Traffic Control  Flashing Signal/Blinker
# 2                Agra  Traffic Control  Flashing Signal/Blinker
# 3                Agra  Traffic Control  Flashing Signal/Blinker
# 4                Agra  Traffic Control  Flashing Signal/Blinker
#
#          Outcome of Incident  Count
# 0         Greviously Injured    0.0
# 1               Minor Injury    0.0
# 2             Persons Killed    0.0
# 3              Total Injured    0.0
# 4  Total number of Accidents    0.0

# %% [markdown]
# # Distribution of Incident Outcomes

# %%
df['Outcome of Incident'].value_counts()
# Out:
# Outcome of Incident
# Total number of Accidents    2000
# Greviously Injured           1999
# Minor Injury                 1999
# Persons Killed               1999
# Total Injured                1550
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(x='Outcome of Incident',data=df,palette='tab20')
plt.xticks(rotation=40)
plt.title('Distribution of Incident Outcomes',fontweight='bold',size=18,fontfamily='Arial')
plt.xlabel('Outcome of Incident',fontweight='bold',size=13)
plt.ylabel('Count',fontweight='bold',size=12)
plt.gcf().set_facecolor('#B3C99C')
for container in ax.containers:
    ax.bar_label(container,fontweight='bold',fontsize=12)
sns.set_style("darkgrid")    
plt.show()

# %% [markdown]
# # Distribution of Cause Subcategory

# %%
df['Cause Subcategory'].value_counts()
# Out:
# Cause Subcategory
# Others                                              1450
# Flashing Signal/Blinker                              250
# Over                                                 250
# Rainy                                                250
# Hail/Sleet                                           250
# Foggy and Misty                                      250
# Straight Road                                        250
# Steep Grade                                          250
# Pot Holes                                            250
# Ongoing Road Works/Under Construction                250
# Curved Road                                          250
# Bridge                                               250
# Use of Mobile Phone                                  250
# Culvert                                              250
# Jumping Red Light                                    250
# Four arm Junction                                    250
# ...

# %%
cause_subcategory= df.groupby('Cause Subcategory')['Count'].mean().reset_index()

# %%
plt.figure(figsize=(12,4))

#sns.barplot(x='Count',y='Cause Subcategory',data=cause_subcategory,palette='icefire')
sns.countplot(x='Cause Subcategory',data=df,palette='gnuplot2_r')
plt.xticks(rotation=90)
plt.title('Distribution of Cause Subcategory',fontweight='bold',size=18,fontfamily='Arial')
plt.xlabel('Cause Subcategory',fontweight='bold',size=18)
plt.ylabel('Count',fontweight='bold',size=18)
plt.gcf().set_facecolor('#B3C99C')
plt.grid(True)
plt.show()

# %% [markdown]
# # Distribution of Cause category

# %%
df['Cause category'].value_counts()
# Out:
# Cause category
# Road Features               2000
# Impacting Vehicle/Object    1797
# Traffic Control             1500
# Junction                    1500
# Traffic Violation           1500
# Weather                     1250
# Name: count, dtype: int64

# %%
cause_category= df.groupby('Cause category')['Count'].mean().reset_index()

# %%
plt.figure(figsize=(12,5))
#sns.barplot(x='Count',y='Cause category',data=cause_category,palette='gnuplot2_r',alpha=0.8,orient='h')
ax=sns.countplot(x='Cause category',data=df,palette='gnuplot2_r',alpha=0.9)
plt.xticks(rotation=90)
plt.title('Distribution of Cause category',fontweight='bold',size=18,fontfamily='Arial')
plt.xlabel('Causes',fontweight='bold',size=18)
plt.ylabel('Count',fontweight='bold',size=18)
plt.gcf().set_facecolor('#B3C99C')
for container in ax.containers:
    ax.bar_label(container,label_type='edge',fontsize=12,fontweight='bold')
plt.show()

# %%
def my_graph(a,col):
    data = df[df['Cause category']==f"{a}"]
    data=data.groupby('Outcome of Incident').sum()[['Count']].sort_values('Count',ascending=False)
    
    plt.figure(figsize=(12, 6))
    ax=plt.bar(data.index, data['Count'], edgecolor='black',color=f'{col}')
    plt.title(f'Outcome of Incident on the bases of {a}', fontsize=18,fontweight='bold')
    plt.xlabel('Incidents', fontsize=18,fontweight='bold')
    plt.ylabel('Incident Count', fontsize=14,fontweight='bold')
    plt.xticks(rotation=90)
    sns.set_context("paper")
    sns.set_style("darkgrid")
    plt.bar_label(ax, padding=3,fontweight='bold',size=14) 
        
    plt.tight_layout()
    plt.gcf().set_facecolor('#B3C99C')
    plt.show()

# %%
for i in df["Cause category"].unique():
    print(i)
# Out:
# Traffic Control
# Junction
# Traffic Violation
# Road Features
# Impacting Vehicle/Object
# Weather

# %%
my_graph("Traffic Control","#FF6969")

# %%
my_graph("Junction","#8093F1")

# %%
my_graph("Traffic Violation","#FD9A4D")

# %%
my_graph("Road Features","#FF8A8A")

# %%
my_graph("Impacting Vehicle/Object","#9F73AB")

# %%
my_graph("Weather","#379237")

# %% [markdown]
# #  A stacked bar plot showing the relationship between accident causes and their outcomes.

# %%
df.head()
# Out:
#   Million Plus Cities   Cause category        Cause Subcategory  \
# 0                Agra  Traffic Control  Flashing Signal/Blinker
# 1                Agra  Traffic Control  Flashing Signal/Blinker
# 2                Agra  Traffic Control  Flashing Signal/Blinker
# 3                Agra  Traffic Control  Flashing Signal/Blinker
# 4                Agra  Traffic Control  Flashing Signal/Blinker
#
#          Outcome of Incident  Count
# 0         Greviously Injured    0.0
# 1               Minor Injury    0.0
# 2             Persons Killed    0.0
# 3              Total Injured    0.0
# 4  Total number of Accidents    0.0

# %%
ax=df.groupby(['Cause category', 'Outcome of Incident']).size().unstack().plot(kind='bar', stacked=True,title='Cause category',
                                grid=True,figsize=(12,6), color=['steelblue','pink','green','purple','orange'],alpha=0.8)

plt.xticks(rotation=90)
plt.legend(loc='upper right')
plt.title(' Relationship between causes and outcomes of road accidents',fontweight='bold',size=17,fontfamily='Arial')
plt.xlabel('Cause category',fontweight='bold',size=18)
plt.ylabel('Count',fontweight='bold',size=18)
plt.gcf().set_facecolor('#B3C99C')
for container in ax.containers:
    ax.bar_label(container,label_type='center',padding=3,fontsize=12,fontweight='bold')
    
plt.show()

# %% [raw]
# The bar plot reveals that road features and vehicles/objects are leading causes of accidents, contributing heavily to injuries and fatalities. Junctions and traffic control issues contribute notably to accidents, with a focus on injuries. Although less frequent, accidents involving Weather conditions still result in serious outcomes. Overall, addressing road conditions, enforcing traffic rules, and improving infrastructure, especially during adverse weather, are crucial to enhancing road safety.

# %% [markdown]
# # Highlight the most common causes of accidents.

# %%
df['Outcome of Incident'].value_counts()
# Out:
# Outcome of Incident
# Total number of Accidents    2000
# Greviously Injured           1999
# Minor Injury                 1999
# Persons Killed               1999
# Total Injured                1550
# Name: count, dtype: int64

# %%
accident= df.groupby(['Cause category','Outcome of Incident']).max()[['Count']].sort_values('Count',ascending=False)

# %%
accident
# Out:
#                                                      Count
# Cause category           Outcome of Incident
# Road Features            Total Injured              3148.0
#                          Total number of Accidents  3134.0
# Traffic Violation        Total number of Accidents  3032.0
# Weather                  Total number of Accidents  3014.0
# Traffic Violation        Total Injured              2801.0
# Road Features            Minor Injury               2676.0
# Weather                  Total Injured              2589.0
# Junction                 Total number of Accidents  2463.0
# Traffic Control          Total number of Accidents  2463.0
# Traffic Violation        Minor Injury               2423.0
# Junction                 Total Injured              2289.0
# Traffic Control          Total Injured              2289.0
# Junction                 Minor Injury               2180.0
# Traffic Control          Minor Injury               2180.0
# ...

# %%
accident_reset = accident.reset_index()

# %%
accident_reset
# Out:
#               Cause category        Outcome of Incident   Count
# 0              Road Features              Total Injured  3148.0
# 1              Road Features  Total number of Accidents  3134.0
# 2          Traffic Violation  Total number of Accidents  3032.0
# 3                    Weather  Total number of Accidents  3014.0
# 4          Traffic Violation              Total Injured  2801.0
# 5              Road Features               Minor Injury  2676.0
# 6                    Weather              Total Injured  2589.0
# 7                   Junction  Total number of Accidents  2463.0
# 8            Traffic Control  Total number of Accidents  2463.0
# 9          Traffic Violation               Minor Injury  2423.0
# 10                  Junction              Total Injured  2289.0
# 11           Traffic Control              Total Injured  2289.0
# 12                  Junction               Minor Injury  2180.0
# 13           Traffic Control               Minor Injury  2180.0
# ...

# %%
pivot_table = accident_reset.pivot(index='Cause category', columns='Outcome of Incident', values='Count').fillna(0)

# %%
plt.figure(figsize=(11, 5))
sns.heatmap(pivot_table, annot=True, fmt='g', cmap='YlGnBu',linecolor='black',linewidths=0.7,alpha=0.9)
plt.gcf().set_facecolor('#B3C99C')
plt.title('To Identify the most common causes of accidents',fontweight='bold',color='black',fontsize=14,fontstyle='italic')
plt.xlabel("Outcome of Incident",fontweight='bold',fontsize=14)
plt.ylabel('Cause category',fontweight='bold',fontsize=14)

plt.show()

# %% [raw]
# 1.Road Features account for the highest number of total injuries (3,148) and accidents (3,134).
# 2.Traffic Violations also significantly contribute to accidents (3,032) and injuries (2,801).
# 3.Weather conditions are another major factor, with (2,589) injuries and 651 deaths.
# 4.Minor Injuries are predominantly caused by Road Features (2,676), Traffic Violations (2,423), and Weather (2,164).
#
# Visualization: The heatmap visualizes this data, with darker colors indicating higher values. This makes it easy to spot which causes lead to the most accidents and severe outcomes.
#
# Most Common Causes: Road Features and Traffic Violations stand out with the highest numbers of accidents and injuries.
# Fatal Incidents: Although fewer, fatalities are highest in Road Features, Traffic Violations, and Weather-related incidents.

# %% [markdown]
# # Distribution of Accidents in Top 10 Cities

# %%
data=df.groupby('Million Plus Cities').sum()[['Count']].sort_values('Count',ascending=False).head(10)

# %%
data
# Out:
#                        Count
# Million Plus Cities
# Chennai              78459.0
# Delhi                72526.0
# Jabalpur             57715.0
# Bengaluru            53535.0
# Indore               50098.0
# Bhopal               35069.0
# Hyderabad            34720.0
# Jaipur               32524.0
# Mallapuram           32294.0
# Mumbai               32106.0

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
explode= [0.1]+ [0]* (len(data)-1)
colors = plt.cm.Paired.colors
plt.pie(data['Count'], labels= data.index, autopct='%1.1f%%',startangle=90, explode=explode,colors=colors,
        textprops={'fontsize': 9, 'fontweight': 'bold'}) 
plt.axis('equal')
plt.title('Distribution of Accidents in Million Plus Cities (Top 10)',size=18,fontweight='bold',color='black')

plt.subplot(1,2,2)
colors = plt.cm.Paired.colors
#explode= [0.1]+ [0]* (len(data)-1)
plt.pie(data['Count'], labels= data.index, autopct='%1.1f%%',startangle=90,colors=colors,
        textprops={'fontsize': 9, 'fontweight': 'bold'}) 
plt.axis('equal')
 
centre_circle = plt.Circle((0,0),0.70,fc='white')
plt.gca().add_artist(centre_circle)
#plt.gcf().set_facecolor('#B3C99C')
plt.tight_layout()
plt.show()

# %% [raw]
# The pie chart represents the distribution of the top 10 cities with the highest 'Count' values among "Million Plus Cities." The data is grouped by the 'Million Plus Cities' feature, and for each city, the total count value is considered. The cities are then sorted in descending order based on their 'Count,' and the top 10 cities are displayed in the chart.
#
# Each slice of the pie corresponds to one of the top cities, with the size of the slice representing the proportion of the city's 'Count' relative to the total of the top 10 cities. The largest slice signifies the city with the highest count, visually emphasized by an exploded slice to highlight the most significant contributor.
#
# Chennai stands out as the leading city, with 78,459 incidents, making it the highest contributor among the cities. Delhi follows with 72,526 incidents, while Jabalpur records 57,715 incidents. The chart provides a clear comparison of incident numbers across these cities, allowing for easy identification of the highest and lowest counts within the top 10.

# %% [markdown]
# # Conclusion and Recommendations for the Road Accident

# %% [markdown]
# # Conclusion

# %% [raw]
# The analysis of road incidents in "Million Plus Cities" reveals that Chennai has the highest number of incidents (78,459), followed by Delhi (72,526) and Jabalpur (57,715). Key causes include road features, traffic violations, and adverse weather, indicating a need for targeted interventions to improve road safety.

# %% [markdown]
# # Recommendations

# %% [raw]
# 1. Targeted Safety Campaigns: Launch city-specific campaigns in Chennai and Delhi focused on traffic violations and road safety    awareness.
#
# 2. Infrastructure Improvements: Upgrade road infrastructure in high-incident areas, including better signage and traffic control    devices.
#
# 3. Enhanced Traffic Enforcement: Strengthen law enforcement to deter traffic violations, using technology for monitoring and        penalties for offenders.
#
# 4. Weather-Related Safety Measures: Implement protocols for adverse weather conditions and develop a mobile app to alert drivers    about hazards.
#
# 5. Data-Driven Decision Making: Establish a continuous data collection system to monitor incidents and evaluate the                effectiveness of safety measures.
#
# 6. Collaboration with Local Governments: Work with local agencies to ensure a unified approach to road safety and enhance         community involvement.
